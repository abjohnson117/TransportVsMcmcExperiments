# %%
import numpy as np
import pickle

# %%
str_list = ["high", "low", "mid"] 
hyperparam_list = []
for i in range(3):
    with open("hyperparam_results/best_hyperparams_" + str_list[i] + ".pkl", "rb") as f:
        hyperparams = pickle.load(f)
    hyperparam_list.append(hyperparams)

# %%
hyperparam_list[2]
# Out:
# {'hidden_layer': 321,
#  'num_hidden_layers': 4,
#  'peak_value': 0.0014578815705,
#  'weight_decay': 1.91583927e-05,
#  'interpolant': 'trig_interpolant'}

# %%
hyperparam_list[1]
# Out:
# {'hidden_layer': 920,
#  'num_hidden_layers': 11,
#  'peak_value': 0.0010184422812,
#  'weight_decay': 0.0017362271089,
#  'interpolant': 'trig_interpolant'}

# %%
hyperparam_list[0]
# Out:
# {'hidden_layer': 389,
#  'num_hidden_layers': 4,
#  'peak_value': 0.0002273850558,
#  'weight_decay': 0.0097920568325,
#  'interpolant': 'trig_interpolant'}
