# %%
import numpy as np
from seaborn import kdeplot
import matplotlib.pyplot as plt
from triangular_transport.flows.methods.sampling import inf_train_gen
plt.style.use("ggplot")

# %%
samps = np.load("rej_results/_0/rej_samps.npy")
ys = np.load("rej_results/_0/conditioning_ys.npy")

# %%
kdeplot(samps[-3, :])
# Out:
# <Axes: ylabel='Density'>

# %%
ys
# Out:
# array([ 0.30264372,  1.33417407,  0.63713293, ...,  0.78347807,
#        -2.50132505,  2.13318636], shape=(65536,))

# %%
g8 = inf_train_gen("8gaussians", batch_size=10000)
plt.scatter(g8[:, 0], g8[:, 1])
